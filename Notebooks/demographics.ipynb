# %% [markdown]
# # Learning about the Demograph of the data for the project

# %% [markdown]
# The data for the project was taken from SensSmartTech Database on Physionet.
# It is polycardiograph of the cardiovascular signals measured synchronously. It consist of Electrocardiograph, phonocardiograph, photoplethysmography and accelerometer. It is consist of 338 30 seconds recordings from 32 healthy volunteers.

# %% [markdown]
# It is made of 10 channels;
#  1. 4 ECG ( limb, V3, V4 leads)
#  2. 1 PCG (measured at the heart apex)
#  3. 4 PPG
#  4. 1 ACC ( accelerometer)

# %% [markdown]
#  Several multisensory databases capturing variations in HR during activity have been documented [5-8]. SensSmartTech stands out as the first base of multisensory recordings which systematically follows heart relaxation dynamics across a wide range of HRs (58 bpm - 173 bpm). The recorded HR-dependence is of interest to clinicians applying the HR biomarker correction, engineers investigating HR estimation by different wearable sensors and the impact of noises and artefacts on diagnostic signals, and scientist studying the underlying nonlinear dynamics of the heart as an electro-mechanical system.

# %% [markdown]
# Of interest to us is the  4 Channel ECG , 1 PCG and 1 ACC counting as 6 channels for the project work.

# %% [markdown]
# ### **Technicalities of the hardware used for taking the data.**
#
# 1. ECG signal acquisition is performed with the ADS1298 chip (Texas Instruments) with the sampling rate set to 500 Hz. Measurement used 4 limb electrodes, V3 and V4, while the redundant precordial electrodes (V1, V2, V5 and V6) were placed on the upper right arm to prevent noise from the hanging leads
#
# 2. PCG signal is captured using a microphone ICS-40300 (TDK InvenSense) placed in a cardiology stethoscope SPIRIT CK-S474SPF63 (Spirit Medical) with the sampling rate of 1 kHz. 1 PCG stethoscope was positioned at the sternum to the right of V3 ECG electrode and secured with an elastic band
#
# 3. ACC signal was recorded by a MEMS accelerometer MPU6050 (TDK InvenSense) with an acceleration range set to +/- 1g. It was attached to the body between V3 and V4 ECG electrodes using a self-adhesive ECG electrode. Only the z axis in the direction perpendicular to the chest was used
#
#  4. Sensors output signals were digitalized by 16 bit A/D converters. The polycardiograph synchronously collected data form the sensors and transmitted them to a PC over Ethernet. Accuracy of the Polycardiograph was set by the sampling rate of the sensors.

# %% [markdown]
# **Relevant information concerning mode of data collection**: Recordings were taken in a standing position at rest and immediately after the activity.
# After each recording, the researcher calculated the heart rate (HR). Three 30-second recordings were made at rest. After the activity, recordings were repeated until the HR dropped to 10-20 bpm above the HR at rest.

# %% [markdown]
# Of interest to us is the CSV format which has column for time, and the rest of the channels associated with it.  The **acquisition time follows the sampling rate of the sensor**. Sensors may record signals at different point in time.
#  Therefore, the time axes of different sensors are different, but the **acquisition is synchronized so that they can be extended to a common zero.**

# %% [markdown]
# Additionally, a table Demographics.csv lists file names and subject demographics, including age, height, weight, and body-mass index. Furthermore, each row in this table displays the subject activity status: 'B' for the measurement before and 'A' for the measurement after the activity, and the HR calculated as the inverse of the median RR interval per recording.
# To de-identify the data, all dates were removed from the recordings. The published data do not contain any information that identifies or provides a reasonable basis to identify an individual. The data comply with HIPPA requirements for sharing personal health information.

# %% [markdown]
# ### **Understanding the Demographics**

# %%
# Loading the necessary Libraries
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from datetime import datetime, timedelta
import seaborn as sns

# %%
# Loading the dataset
df = pd.read_csv('Demographics_Cleaned.csv', )
# Display the first few rows of the DataFrame to understand its structure
df.head()
# Out:
#    File Number  Subject number Recording time (hh:mm:ss) Gender  Age (year)  \
# 0          1.0             1.0                  10:09:54      M        53.0
# 1          2.0             1.0                  10:11:48      M        53.0
# 2          3.0             1.0                  10:12:41      M        53.0
# 3          4.0             1.0                  10:25:13      M        53.0
# 4          5.0             1.0                  10:26:08      M        53.0
#
#    Height (cm)  Weight (kg)  Body-mass index             ECG             PPG  \
# 0        175.0         88.0            28.73  1_10-09-54_ecg  1_10-09-54_ppg
# 1        175.0         88.0            28.73  1_10-11-48_ecg  1_10-11-48_ppg
# 2        175.0         88.0            28.73  1_10-12-41_ecg  1_10-12-41_ppg
# 3        175.0         88.0            28.73  1_10-25-13_ecg  1_10-25-13_ppg
# 4        175.0         88.0            28.73  1_10-26-08_ecg  1_10-26-08_ppg
#
#               PCG             ACC Before (B)  / after (A) activity  \
# 0  1_10-09-54_pcg  1_10-09-54_acc                                B
# 1  1_10-11-48_pcg  1_10-11-48_acc                                B
# 2  1_10-12-41_pcg  1_10-12-41_acc                                B
# 3  1_10-25-13_pcg  1_10-25-13_acc                                A
# 4  1_10-26-08_pcg  1_10-26-08_acc                                A
#
#    Median heart rate (bpm)
# 0                     91.2
# 1                     90.1
# 2                     92.9
# 3                    129.9
# 4                    120.0

# %%
# Check for missing values in the DataFrame
missing_values = df.isnull().sum()
print("Missing values in each column:\n", missing_values)
df.info()
# Out:
# Missing values in each column:
#  File Number                         63
# Subject number                      63
# Recording time (hh:mm:ss)           63
# Gender                              63
# Age (year)                          63
# Height (cm)                         63
# Weight (kg)                         63
# Body-mass index                     63
# ECG                                 63
# PPG                                 63
# PCG                                 63
# ACC                                 63
# Before (B)  / after (A) activity    63
# Median heart rate (bpm)             63
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 401 entries, 0 to 400
# Data columns (total 14 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   File Number                       338 non-null    float64
#  1   Subject number                    338 non-null    float64
#  2   Recording time (hh:mm:ss)         338 non-null    object
#  3   Gender                            338 non-null    object
#  4   Age (year)                        338 non-null    float64
#  5   Height (cm)                       338 non-null    float64
#  6   Weight (kg)                       338 non-null    float64
#  7   Body-mass index                   338 non-null    float64
#  8   ECG                               338 non-null    object
#  9   PPG                               338 non-null    object
#  10  PCG                               338 non-null    object
#  11  ACC                               338 non-null    object
#  12  Before (B)  / after (A) activity  338 non-null    object
#  13  Median heart rate (bpm)           338 non-null    float64
# dtypes: float64(7), object(7)
# memory usage: 44.0+ KB

# %% [markdown]
# In cleaning the data: There are no empty record within the data.
# The data demographics needs to be changed to fit into our calculation and Exploratory Data Analysis (EDA)

# %%
# Convert 'Recording time' string to datetime.time object
# Recording time (hh:mm:ss) is the column with time strings
# Function to safely convert time strings to datetime.time objects

def parse_time(val):
    if pd.isna(val):
        return None
    try:
        return datetime.strptime(str(val).strip(), "%H:%M:%S").time()
    except ValueError:
        print(f"Skipping invalid time format: {val}")
        return None

# Apply the conversion
df["Recording time"] = df["Recording time (hh:mm:ss)"].apply(parse_time)


# Group by Subject number and sort within each group by File number

grouped = df.groupby("Subject number")

# Create a dictionary where key = Subject number, value = DataFrame of that subject's records

subject_batches = {
    subject: group.sort_values(by="File Number").reset_index(drop=True)
    for subject, group in grouped
}

# Display the first few rows of the DataFrame for a specific subject (e.g., Subject 1)

subject_batches[1].head(10)
# Out:
#    File Number  Subject number Recording time (hh:mm:ss) Gender  Age (year)  \
# 0          1.0             1.0                  10:09:54      M        53.0
# 1          2.0             1.0                  10:11:48      M        53.0
# 2          3.0             1.0                  10:12:41      M        53.0
# 3          4.0             1.0                  10:25:13      M        53.0
# 4          5.0             1.0                  10:26:08      M        53.0
# 5          6.0             1.0                  10:26:55      M        53.0
# 6          7.0             1.0                  10:27:42      M        53.0
# 7          8.0             1.0                  10:29:01      M        53.0
# 8          9.0             1.0                  10:31:08      M        53.0
# 9         10.0             1.0                  10:32:38      M        53.0
#
#    Height (cm)  Weight (kg)  Body-mass index             ECG             PPG  \
# 0        175.0         88.0            28.73  1_10-09-54_ecg  1_10-09-54_ppg
# 1        175.0         88.0            28.73  1_10-11-48_ecg  1_10-11-48_ppg
# 2        175.0         88.0            28.73  1_10-12-41_ecg  1_10-12-41_ppg
# 3        175.0         88.0            28.73  1_10-25-13_ecg  1_10-25-13_ppg
# 4        175.0         88.0            28.73  1_10-26-08_ecg  1_10-26-08_ppg
# 5        175.0         88.0            28.73  1_10-26-55_ecg  1_10-26-55_ppg
# 6        175.0         88.0            28.73  1_10-27-42_ecg  1_10-27-42_ppg
# 7        175.0         88.0            28.73  1_10-29-01_ecg  1_10-29-01_ppg
# 8        175.0         88.0            28.73  1_10-31-08_ecg  1_10-31-08_ppg
# 9        175.0         88.0            28.73  1_10-32-38_ecg  1_10-32-38_ppg
#
#               PCG             ACC Before (B)  / after (A) activity  \
# 0  1_10-09-54_pcg  1_10-09-54_acc                                B
# 1  1_10-11-48_pcg  1_10-11-48_acc                                B
# 2  1_10-12-41_pcg  1_10-12-41_acc                                B
# 3  1_10-25-13_pcg  1_10-25-13_acc                                A
# 4  1_10-26-08_pcg  1_10-26-08_acc                                A
# 5  1_10-26-55_pcg  1_10-26-55_acc                                A
# 6  1_10-27-42_pcg  1_10-27-42_acc                                A
# 7  1_10-29-01_pcg  1_10-29-01_acc                                A
# 8  1_10-31-08_pcg  1_10-31-08_acc                                A
# 9  1_10-32-38_pcg  1_10-32-38_acc                                A
#
#    Median heart rate (bpm) Recording time
# 0                     91.2       10:09:54
# 1                     90.1       10:11:48
# 2                     92.9       10:12:41
# 3                    129.9       10:25:13
# 4                    120.0       10:26:08
# 5                    112.8       10:26:55
# 6                    111.1       10:27:42
# 7                    110.3       10:29:01
# 8                    113.2       10:31:08
# 9                    104.9       10:32:38

# %%
# Creating the duration DataFrame
# rows with NaN in 'Recording time' is dropped to avoid errors in calculations

df_clean = df.dropna(subset=["Recording time"])

# Group by Subject
subject_groups = df_clean.groupby("Subject number")

# Prepare results
duration_data = []

for subject, group in subject_groups:
    group_sorted = group.sort_values("File Number")

    start_time = group_sorted["Recording time"].iloc[0]
    end_time = group_sorted["Recording time"].iloc[-1]

    # Convert times to datetime so we can subtract
    start_dt = datetime.combine(datetime.today(), start_time)
    end_dt = datetime.combine(datetime.today(), end_time)

    # Handle potential midnight wraparound (if needed)
    if end_dt < start_dt:
        end_dt += timedelta(days=1)

    duration = end_dt - start_dt

    duration_data.append({
        "Subject number": subject,
        "Start time": start_time,
        "End time": end_time,
        "Duration (HH:MM:SS)": duration
    })

# Create a new DataFrame with the results
duration_df = pd.DataFrame(duration_data)
duration_df
# Out:
#     Subject number Start time  End time Duration (HH:MM:SS)
# 0              1.0   10:09:54  10:32:38     0 days 00:22:44
# 1              2.0   14:08:15  14:35:20     0 days 00:27:05
# 2              3.0   10:08:25  10:23:07     0 days 00:14:42
# 3              4.0   11:19:22  11:29:07     0 days 00:09:45
# 4              5.0   08:59:04  09:14:32     0 days 00:15:28
# 5              6.0   10:43:42  11:26:54     0 days 00:43:12
# 6              7.0   14:16:33  14:29:51     0 days 00:13:18
# 7              8.0   12:52:50  13:21:39     0 days 00:28:49
# 8              9.0   13:52:23  14:10:21     0 days 00:17:58
# 9             10.0   18:12:33  18:34:40     0 days 00:22:07
# 10            11.0   18:48:54  19:07:12     0 days 00:18:18
# 11            12.0   19:23:52  19:36:02     0 days 00:12:10
# 12            13.0   20:07:34  20:17:55     0 days 00:10:21
# 13            14.0   09:29:28  09:43:45     0 days 00:14:17
# 14            15.0   10:09:00  10:28:18     0 days 00:19:18
# 15            16.0   10:50:04  11:12:40     0 days 00:22:36
# 16            17.0   08:34:00  08:53:23     0 days 00:19:23
# 17            18.0   10:28:07  10:42:04     0 days 00:13:57
# 18            19.0   14:37:08  15:05:30     0 days 00:28:22
# 19            20.0   15:29:10  15:49:37     0 days 00:20:27
# 20            21.0   14:20:02  14:28:51     0 days 00:08:49
# 21            22.0   10:24:09  10:44:14     0 days 00:20:05
# 22            23.0   13:36:01  13:51:05     0 days 00:15:04
# 23            24.0   14:13:24  14:25:50     0 days 00:12:26
# 24            25.0   13:45:17  13:55:32     0 days 00:10:15
# 25            26.0   15:40:47  15:58:23     0 days 00:17:36
# 26            27.0   10:37:56  11:05:56     0 days 00:28:00
# 27            28.0   11:49:45  12:06:12     0 days 00:16:27
# 28            29.0   09:49:57  10:09:09     0 days 00:19:12
# 29            30.0   10:18:52  10:33:16     0 days 00:14:24
# 30            31.0   11:17:40  11:37:07     0 days 00:19:27
# 31            32.0   12:05:18  12:22:15     0 days 00:16:57

# %%
#Trying to group the data according to the before and after activity (A and B) and calculate the duration of each activity.

# Clean the activity column (strip whitespace and uppercase)
df["Activity"] = df["Before (B)  / after (A) activity"].astype(str).str.strip().str.upper()

# Drop rows with missing info
df_clean = df.dropna(subset=["Recording time", "Activity"])

# Prepare results
results = []

for subject, group in df_clean.groupby("Subject number"):
    subject_data = {"Subject number": subject}

    for label in ['A', 'B']:  # A = After, B = Before
        sub = group[group["Activity"] == label]

        if sub.empty:
            subject_data[f"{label} Start"] = None
    'B': '#C44E52'   # muted red
}

# Plot
ax = pivot_df.plot(
    kind='bar',
    stacked=True,
    color=[colors.get(col) for col in pivot_df.columns],
    figsize=(15, 6),
    edgecolor='black'
)

# Title and labels
plt.title("Stacked Probability Distribution of Heart Rate Measurements", fontsize=14)
plt.xlabel("Subject Number", fontsize=12)
plt.ylabel("Probability", fontsize=12)
plt.xticks(rotation=0)
plt.legend(title="Activity", title_fontsize=11, fontsize=10)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Add value labels
for idx, row in pivot_df.iterrows():
    cumulative = 0
    for activity in pivot_df.columns:
        height = row[activity]
        if height > 0:
            ax.text(idx, cumulative + height / 2, f"{height:.2f}", ha='center', va='center', fontsize=9, color='white')
            cumulative += height

plt.tight_layout()
plt.show()

# %%
subject_info = df[["Subject number","Age (year)","Height (cm)","Weight (kg)","Body-mass index"]]

# Drop duplicates so each subject appears only once
unique_subject_info = subject_info.drop_duplicates(subset=["Subject number"])

# (Optional) Set subject as index
unique_subject_info.set_index("Subject number", inplace=True)
unique_subject_info
# Out:
#                 Age (year)  Height (cm)  Weight (kg)  Body-mass index
# Subject number
# 1.0                   53.0        175.0         88.0            28.73
# 2.0                   27.0        169.0         63.0            22.06
# 3.0                   25.0        189.0        101.0            28.27
# 4.0                   31.0        200.0        113.0            28.25
# 5.0                   44.0        167.0         64.0            22.95
# 6.0                   37.0        170.0         86.0            29.76
# 7.0                   33.0        160.0         54.0            21.09
# 8.0                   44.0        181.0         78.0            23.81
# 9.0                   28.0        167.0         60.0            21.51
# 10.0                  25.0        169.0         64.0            22.41
# 11.0                  24.0        178.0         71.0            22.41
# 12.0                  25.0        178.0         71.0            22.41
# 13.0                  25.0        178.0         70.0            22.09
# 14.0                  39.0        186.0        113.0            32.66
# 15.0                  55.0        168.0         81.0            28.70
# 16.0                  31.0        169.0         67.0            23.46
# 17.0                  30.0        157.0         60.0            24.34
# 18.0                  39.0        175.0         68.0            22.20
# 19.0                  36.0        178.0         74.0            23.36
# 20.0                  40.0        190.0        114.0            31.58
# 21.0                  25.0        170.0         60.0            20.76
# 22.0                  26.0        180.0         85.0            26.23
# 23.0                  27.0        175.0         70.0            22.86
# 24.0                  37.0        180.0         87.0            26.85
# 25.0                  31.0        167.0         61.0            21.87
# 26.0                  28.0        182.0         70.0            21.13
# 27.0                  32.0        173.0         60.0            20.05
# 28.0                  37.0        160.0         68.0            26.56
# 29.0                  28.0        180.0        120.0            37.04
# 30.0                  52.0        176.0        105.0            33.90
# 31.0                  42.0        186.0         80.0            23.12
# 32.0                  50.0        170.0         70.0            24.22
# NaN                    NaN          NaN          NaN              NaN

# %%
new_df = unique_subject_info.join(duration_df.set_index("Subject number"), on="Subject number", how="inner")
mean_series = heart_rate_distr["mean"]
mean_df = mean_series.unstack("Before (B)  / after (A) activity")
mean_df = mean_df.reset_index()
mean_df.columns = ['Subject number', 'heart_rate_Before', 'heart_rate_After']
new_df = new_df.join(mean_df.set_index("Subject number"), on="Subject number", how="left")
new_df
# Out:
#                 Age (year)  Height (cm)  Weight (kg)  Body-mass index  \
# 24.0             14:13:24  14:25:50     0 days 00:12:26         117.683333
# 25.0             13:45:17  13:55:32     0 days 00:10:15          95.483333
# 26.0             15:40:47  15:58:23     0 days 00:17:36          96.857143
# 27.0             10:37:56  11:05:56     0 days 00:28:00         114.275000
# 28.0             11:49:45  12:06:12     0 days 00:16:27         105.260000
# 29.0             09:49:57  10:09:09     0 days 00:19:12         121.150000
# 30.0             10:18:52  10:33:16     0 days 00:14:24         115.066667
# 31.0             11:17:40  11:37:07     0 days 00:19:27         122.557143
# 32.0             12:05:18  12:22:15     0 days 00:16:57         112.027273
#
#                 heart_rate_After
# Subject number
# 1.0                    91.400000
# 2.0                    86.000000
# 3.0                    95.400000
# 4.0                    66.550000
# 5.0                    94.300000
# 6.0                    82.850000
# 7.0                    74.966667
# 8.0                    90.400000
# 9.0                    75.833333
# 10.0                   95.833333
# 11.0                   98.300000
# 12.0                   88.925000
# 13.0                   68.033333
# 14.0                   90.300000
# 15.0                   95.533333
# 16.0                  100.866667
# 17.0                   90.350000
# 18.0                  100.200000
# 19.0                  103.100000
# 20.0                   89.300000
# 21.0                   71.400000
# 22.0                  101.233333
# 23.0                   90.200000
# 24.0                   95.600000
# 25.0                   68.966667
# 26.0                   60.050000
# 27.0                   81.500000
# 28.0                   82.533333
# 29.0                   90.000000
# 30.0                   81.300000
# 31.0                   87.200000
# 32.0                   78.066667

# %%
# new_df.to_csv("Final_Demographics.csv", index=False)

# I have had my fair share of challenges with the code, but I have tried to make it as clean as possible.
# I have also tried to make the code as efficient as possible. I have used functions and loops where necessary to avoid redundancy.
# I have also used pandas and numpy to handle the data efficiently. I have used groupby and apply functions to manipulate the data.

# %% [markdown]
# ### Univariate Analysis

# %% [markdown]
# Before analyzing individual heart rate responses, it is essential to first understand the baseline characteristics of the volunteer population. This univariate analysis focuses on the core demographic and biometric variables — age, height, weight, and body mass index (BMI). By examining the distribution and statistical properties of each variable independently, we can gain valuable insight into the nature of the dataset and the population it represents.

# %% [markdown]
# By analyzing these features independently, we aim to observe the general characteristics of the volunteer population and identify any potential skewness, outliers, or concentration patterns. Understanding the nature of these variables helps assess their possible influence on subsequent measurements, particularly the heart rate readings recorded before and after physical activity
#
# This stage sets the groundwork for deeper exploration, where we will evaluate the relationships between these biometric factors and physiological responses to activity. Each volunteer's data is recorded at two distinct time points—before and after activity—and will later be used for statistical comparison and signal-based interpretation.

# %%
columns_to_plot = [
    "Age (year)",
    "Height (cm)",
    "Weight (kg)",
    "Body-mass index"
]

fig, axs = plt.subplots(2, 2, figsize=(12, 8))
axs = axs.flatten()

for i, col in enumerate(columns_to_plot):
    sns.histplot(unique_subject_info[col], kde=True, ax=axs[i], color="lightcoral", edgecolor="black")
    axs[i].set_title(f"{col} Distribution")
    axs[i].set_xlabel(col)
    axs[i].set_ylabel("Frequency")
    axs[i].grid(True, linestyle="--", alpha=0.5)

plt.tight_layout()
plt.show()

# %% [markdown]
# The dataset consists of demographic and biometric features, including age, height, weight, and body mass index (BMI). The age distribution is right-skewed, indicating a predominantly younger population, with most individuals falling between 25 and 30 years old. The height distribution follows a roughly normal (bell-shaped) curve, centered around 175–180 cm, suggesting consistent height variation across the sample. Weight and BMI distributions are also right-skewed, with most participants weighing between 60 and 80 kg and having a BMI between 20 and 25, which corresponds to the healthy range. The skewness in weight and BMI implies the presence of a few participants with higher values, but overall, the data reflects a generally healthy group of younger adults. These distributions are essential for understanding the characteristics of the sample and may influence the design or interpretation of any health-related or physiological analysis conducted on this population.

# %% [markdown]
# ### Multivariate Analysis

# %%
sns.pairplot(new_df[['Age (year)', 'Height (cm)', 'Weight (kg)', 'Body-mass index','heart_rate_Before',
       'heart_rate_After']], diag_kind='kde', palette='coolwarm')
plt.show()
# Out:
# c:\Users\abusu\anaconda3\envs\ProJect64\Lib\site-packages\seaborn\axisgrid.py:1513: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# c:\Users\abusu\anaconda3\envs\ProJect64\Lib\site-packages\seaborn\axisgrid.py:1513: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# c:\Users\abusu\anaconda3\envs\ProJect64\Lib\site-packages\seaborn\axisgrid.py:1513: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# c:\Users\abusu\anaconda3\envs\ProJect64\Lib\site-packages\seaborn\axisgrid.py:1513: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# c:\Users\abusu\anaconda3\envs\ProJect64\Lib\site-packages\seaborn\axisgrid.py:1513: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# c:\Users\abusu\anaconda3\envs\ProJect64\Lib\site-packages\seaborn\axisgrid.py:1513: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# c:\Users\abusu\anaconda3\envs\ProJect64\Lib\site-packages\seaborn\axisgrid.py:1615: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)
# c:\Users\abusu\anaconda3\envs\ProJect64\Lib\site-packages\seaborn\axisgrid.py:1615: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)
# c:\Users\abusu\anaconda3\envs\ProJect64\Lib\site-packages\seaborn\axisgrid.py:1615: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)
# c:\Users\abusu\anaconda3\envs\ProJect64\Lib\site-packages\seaborn\axisgrid.py:1615: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)
# c:\Users\abusu\anaconda3\envs\ProJect64\Lib\site-packages\seaborn\axisgrid.py:1615: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)
# c:\Users\abusu\anaconda3\envs\ProJect64\Lib\site-packages\seaborn\axisgrid.py:1615: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)
# c:\Users\abusu\anaconda3\envs\ProJect64\Lib\site-packages\seaborn\axisgrid.py:1615: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)
# c:\Users\abusu\anaconda3\envs\ProJect64\Lib\site-packages\seaborn\axisgrid.py:1615: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)
# c:\Users\abusu\anaconda3\envs\ProJect64\Lib\site-packages\seaborn\axisgrid.py:1615: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)
# c:\Users\abusu\anaconda3\envs\ProJect64\Lib\site-packages\seaborn\axisgrid.py:1615: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)
# c:\Users\abusu\anaconda3\envs\ProJect64\Lib\site-packages\seaborn\axisgrid.py:1615: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)
# c:\Users\abusu\anaconda3\envs\ProJect64\Lib\site-packages\seaborn\axisgrid.py:1615: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)
# c:\Users\abusu\anaconda3\envs\ProJect64\Lib\site-packages\seaborn\axisgrid.py:1615: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)
# c:\Users\abusu\anaconda3\envs\ProJect64\Lib\site-packages\seaborn\axisgrid.py:1615: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)
# c:\Users\abusu\anaconda3\envs\ProJect64\Lib\site-packages\seaborn\axisgrid.py:1615: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)
# c:\Users\abusu\anaconda3\envs\ProJect64\Lib\site-packages\seaborn\axisgrid.py:1615: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)
# c:\Users\abusu\anaconda3\envs\ProJect64\Lib\site-packages\seaborn\axisgrid.py:1615: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)
# c:\Users\abusu\anaconda3\envs\ProJect64\Lib\site-packages\seaborn\axisgrid.py:1615: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)
# c:\Users\abusu\anaconda3\envs\ProJect64\Lib\site-packages\seaborn\axisgrid.py:1615: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)
# c:\Users\abusu\anaconda3\envs\ProJect64\Lib\site-packages\seaborn\axisgrid.py:1615: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)
# c:\Users\abusu\anaconda3\envs\ProJect64\Lib\site-packages\seaborn\axisgrid.py:1615: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)
# c:\Users\abusu\anaconda3\envs\ProJect64\Lib\site-packages\seaborn\axisgrid.py:1615: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)
# c:\Users\abusu\anaconda3\envs\ProJect64\Lib\site-packages\seaborn\axisgrid.py:1615: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)
# c:\Users\abusu\anaconda3\envs\ProJect64\Lib\site-packages\seaborn\axisgrid.py:1615: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)
# c:\Users\abusu\anaconda3\envs\ProJect64\Lib\site-packages\seaborn\axisgrid.py:1615: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)
# c:\Users\abusu\anaconda3\envs\ProJect64\Lib\site-packages\seaborn\axisgrid.py:1615: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)
# c:\Users\abusu\anaconda3\envs\ProJect64\Lib\site-packages\seaborn\axisgrid.py:1615: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)
# c:\Users\abusu\anaconda3\envs\ProJect64\Lib\site-packages\seaborn\axisgrid.py:1615: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)
# c:\Users\abusu\anaconda3\envs\ProJect64\Lib\site-packages\seaborn\axisgrid.py:1615: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)
# c:\Users\abusu\anaconda3\envs\ProJect64\Lib\site-packages\seaborn\axisgrid.py:1615: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)

# %% [markdown]
# The pairplot illustrates the relationships between age, height, weight, body-mass index (BMI), and heart rates (before and after activity). There is a strong positive correlation between weight and BMI, as well as between height and weight—demonstrating biologically expected trends. Heart rates before and after activity are also positively correlated, indicating consistency in cardiovascular response. Most variables, particularly BMI and weight, display right-skewed distributions, whereas height and heart rates are more normally distributed. Age does not exhibit strong correlations with other features, suggesting it may have limited influence on physical metrics or heart rate response in this sample. Overall, the pairplot provides valuable insight into the interplay between biometric and physiological variables.

# %%
correlation_matrix = new_df[['Age (year)', 'Height (cm)', 'Weight (kg)', 'Body-mass index','heart_rate_Before',
       'heart_rate_After']].corr()

# Set the figure size
plt.figure(figsize=(10, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
# A multivariate analysis focusing on heart rate before and after activity reveals a strong positive correlation (r = 0.69), indicating that individuals with higher resting heart rates tend to exhibit higher post-activity heart rates. This consistent relationship is also evident in the pairplot, where a clear linear trend is visible between the two variables. In contrast, other features such as age, height, weight, and BMI exhibit minimal correlation with heart rate, suggesting that biometric parameters are not strong predictors of cardiovascular response in this sample. The lack of strong associations may reflect the relatively young and healthy nature of the participants or the influence of unmeasured factors such as fitness level or stress. Overall, heart rate dynamics appear to be internally consistent but largely independent of basic anthropometric measures in this dataset.

# %% [markdown]
# #### Key Correlations (from the Heatmap)
# Heart_rate_Before vs Heart_rate_After:
# Correlation = 0.69
# This is a strong positive correlation, suggesting that individuals with higher resting heart rates tend to also have higher heart rates after activity.
#
# *Heart_rate_Before & Other Variables*:
# Very low correlation with age (0.03), height (-0.04), weight (0.01), and BMI (0.05) — indicating resting heart rate is largely independent of these variables in this dataset.
#
# *Heart_rate_After & Other Variables*:
# Weak correlation with age (0.14), weight (0.12), BMI (0.19), and almost none with height (0.00).
#
# 📈 **Visual Trends (from the Pairplot)**
# The scatterplot between heart rate before and after shows a clear positive trend, consistent with the correlation.
# The other scatterplots involving heart rate (vs age, height, BMI, weight) show diffuse clouds with no clear linear trends, supporting the low correlations seen in the heatmap.
#
# 🧠 **Interpretation and Insights**
# The strongest and most meaningful multivariate relationship related to heart rate is the before vs. after pairing. This could indicate consistent cardiovascular profiles — people with higher baseline heart rates show proportionally higher responses to activity.
# However, other biometric factors (age, BMI, etc.) are not strong predictors of heart rate in this population. This might be due to:
# A relatively homogeneous sample (young, healthy adults),or that other unmeasured factors (like fitness level, stress, or caffeine) are more influential.
